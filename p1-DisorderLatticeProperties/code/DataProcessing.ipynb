# %%
from resources.imports import *

from resources.MLdata import DATA
from resources.data_processing import create_inputCSV, create_outputCSV, create_fieldNPZ

# %%
# %load_ext autoreload
# %autoreload 2

# %%
runINOUT = True
runFieldOUT = True

# %%
# for LAT in ["tri", "FCC", "kagome", "hex"]:
#     for add in ["", "Target-xs"]:
#         DAT = DATA(path=1,
#                     path_add=add,
#                     LAT=LAT,
#                     dis="disNodes",
#                     dN=0.2,
#                     mechMode="both")

#         if runINOUT:
#             UTdisNodesINn_df, UTdisNodesINf_df, UTdisStrutsINs_df, UTdisStrutsINf_df, FTdisNodesINn_df, FTdisNodesINf_df, FTdisStrutsINs_df, FTdisStrutsINf_df = create_inputCSV(DAT.PATH, DAT)
#             UTdisNodesOUT_df, UTdisStrutsOUT_df, FTdisNodesOUT_df, FTdisStrutsOUT_df, UTdisNodesINn_df, UTdisNodesINf_df, UTdisStrutsINs_df, UTdisStrutsINf_df, FTdisNodesINn_df, FTdisNodesINf_df, FTdisStrutsINs_df, FTdisStrutsINf_df = create_outputCSV(DAT.PATH, DAT)

#         if runFieldOUT:
#             UTfield_df, FTfield_df = create_fieldNPZ(DAT.PATH, DAT)

# %%
DAT = DATA(path=r"Z:/p1/data/Ti/disNodes/0.2/FCC/sims2",
            path_add="",
            LAT="FCC",
            dis="disNodes",
            dN=0.2,
            mechMode="both")

if runINOUT:
    UTdisNodesINn_df, UTdisNodesINf_df, UTdisStrutsINs_df, UTdisStrutsINf_df, FTdisNodesINn_df, FTdisNodesINf_df, FTdisStrutsINs_df, FTdisStrutsINf_df = create_inputCSV(DAT.PATH, DAT)
    UTdisNodesOUT_df, UTdisStrutsOUT_df, FTdisNodesOUT_df, FTdisStrutsOUT_df, UTdisNodesINn_df, UTdisNodesINf_df, UTdisStrutsINs_df, UTdisStrutsINf_df, FTdisNodesINn_df, FTdisNodesINf_df, FTdisStrutsINs_df, FTdisStrutsINf_df = create_outputCSV(DAT.PATH, DAT)

if runFieldOUT:
    UTfield_df, FTfield_df = create_fieldNPZ(DAT.PATH, DAT)
