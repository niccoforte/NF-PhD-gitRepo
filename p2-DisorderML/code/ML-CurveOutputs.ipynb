# %%
from resources.imports import *

import torch
import torch.nn as nn

from resources.MLdata import DATA
from resources.MLfunc import EarlyStopping, CombinedCurveLoss, QuantileLoss, QuantileLossMATLAB
from resources.MLfunc import hOpt_model, hOpt_compare, hOpt_best_summary
from resources.MLmodels import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Stress-Strain Curve

# %% [markdown]
# ## Multi-Layer Perceptrion (MLP)

# %% [markdown]
# ### DATA

# %%
DAT_MLP = DATA(
    path=1, 
    path_add="",
    load=True, 
    load_split=False,
    split_frac=0.9,
    split_seed=42,
    range_split=(True, False),
    save_split=False,
    LAT="FCC", 
    dis="disNodes", 
    dN=0.2,
    d_data="in",
    mechMode="UT",
    nsims=None,
    model="MLP",
    scale=("symm", "inout"),
    reduce_dim=False, #("PCA", "out", 0.95, 10, True)
    round_decimals=5
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
DAT = DAT_MLP
if DAT.UTmechTest:
    print("UT shape:", DAT.UT_train_in.shape, DAT.UT_train_out.shape)
    print("Train -  in (min, max):", DAT.UT_train_in.min(), DAT.UT_train_in.max(), "\n        out (min, max):", DAT.UT_train_out.min(), DAT.UT_train_out.max())
    print("  Val -  in (min, max):", DAT.UT_val_in.min(), DAT.UT_val_in.max(), "\n        out (min, max):", DAT.UT_val_out.min(), DAT.UT_val_out.max())
    print(" Test -  in (min, max):", DAT.UT_test_in.min(), DAT.UT_test_in.max(), "\n        out (min, max):", DAT.UT_test_out.min(), DAT.UT_test_out.max())
    if DAT.FTmechTest: print("\n========================================================\n")
if DAT.FTmechTest:
    print("FT shape:", DAT.FT_train_in.shape, DAT.FT_train_out.shape)
    print("Train -  in (min, max):", DAT.FT_train_in.min(), DAT.FT_train_in.max(), "\n        out (min, max):", DAT.FT_train_out.min(), DAT.FT_train_out.max())
    print("  Val -  in (min, max):", DAT.FT_val_in.min(), DAT.FT_val_in.max(), "\n        out (min, max):", DAT.FT_val_out.min(), DAT.FT_val_out.max())
    print(" Test -  in (min, max):", DAT.FT_test_in.min(), DAT.FT_test_in.max(), "\n        out (min, max):", DAT.FT_test_out.min(), DAT.FT_test_out.max())
# Out:
# UT shape: (5561, 1444) (5561, 201)
# Train -  in (min, max): -1.0 1.0
#         out (min, max): -1.0 1.0
#   Val -  in (min, max): -1.0 1.0
#         out (min, max): -1.6191947669483455 1.103937947512592
#  Test -  in (min, max): -1.0 1.0
#         out (min, max): -1.595077081066206 1.0862485225493743

# %% [markdown]
# ### HPO

# %%
# HYPERPARAMETER OPTIMIZATION HERE.
# Full HPO run on the full DATA split. Re-running resumes the saved Optuna study.

MLP_hOpt_model_space = {
    "depth": [2, 3, 4, 5],
    "width": [128, 256, 512],
    "block": ["mlp", "res"],
    "act": ["relu", "gelu", "mish"],
    "norm": [None, "batch", "layer"],
    "dropout": {"type": "float", "low": 0.0, "high": 0.25},
    "head_norm": [None, "layer"],
    "head_dropout": {"type": "float", "low": 0.0, "high": 0.20},
}

MLP_hOpt_loss_space = {
    "family": ["mse", "combined"],
    "mse_weight": [0.25, 0.5, 1.0],
    "weighted_mse_weight": [0.0, 0.5, 1.0, 2.0],
    "derivative_weight": [0.0, 0.02, 0.05, 0.10],
    "peak_weight": [0.0, 0.10, 0.25, 0.50],
    "energy_weight": [0.0, 0.05, 0.10, 0.25],
    "peak_location_weight": [0.0, 0.02, 0.05],
    "reduction": ["mean"],
    "derivative_order": [1],
    "SoftPeak_beta": [10.0, 20.0, 40.0],
    "UT": {
        "zone_boundaries": (65, 130),
        "zone_weights": (1.0, 5.0, 0.2),
    },
    "FT": {
        "zone_boundaries": (85, 160),
        "zone_weights": (1.0, 5.0, 0.2),
    },
}

MLP_hOpt_train_space = {
    "optimizer": ["adamw"],
    "lr": {"type": "float", "low": 5e-5, "high": 2e-3, "log": True},
    "weight_decay": {"type": "float", "low": 1e-8, "high": 1e-3, "log": True},
    "batch": [16, 32, 64],
    "n_epochs": {"type": "fixed", "value": 250},
    "metric": ["rmse"],
    "scheduler": ["plateau"],
    "scheduler_factor": [0.3, 0.5],
    "scheduler_patience": [10, 20],
    "scheduler_threshold": {"type": "fixed", "value": 1e-4},
    "early_stop": [True],
    "early_stop_patience": [30, 50],
    "early_stop_min_delta": {"type": "fixed", "value": 1e-5},
    "verbose": {"type": "fixed", "value": 0},
}

study_MLP_full = hOpt_model(
    typ="mlp",
    data=DAT_MLP,
    n_trials=50,
    model_space=MLP_hOpt_model_space,
    loss_space=MLP_hOpt_loss_space,
    train_space=MLP_hOpt_train_space,
    seed=42,
    device=device,
    save=True,
    save_best_model=True,
    name="MLP_full_hOpt",
    n_jobs=1,
    show_progress_bar=True,
)

hOpt_best_summary(study_MLP_full)
# Out:
# c:\Users\exy053\Documents\00-PhD-gitRepo\.venv311\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# c:\Users\exy053\Documents\00-PhD-gitRepo\.venv311\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``group`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# C:\Users\exy053\Documents\00-PhD-gitRepo\resources\MLfunc.py:2200: ExperimentalWarning: PatientPruner is experimental (supported from v2.8.0). The interface can change in the future.
#   pruner = optuna.pruners.PatientPruner(base_pruner, patience=5) if hasattr(optuna.pruners, "PatientPruner") else base_pruner
# [I 2026-05-14 18:59:34,323] A new study created in RDB with name: MLP_full_hOpt
#   0%|          | 0/50 [00:00<?, ?it/s]
#  -> Epoch 1/250 || LOSS - train: 53.583874, val: 14.438961 | MSE - train: 0.410989, val: 0.381455 | RMSE - train: 0.641084, val: 0.617620 | LR: 1.58e-04
# ================ Training Complete ================
#  Best Epoch: 78, with LOSS: 0.945959, MSE: 0.138678 and RMSE: 0.372395 ==================
# UT val metrics | MAE: 3.241986, MSE: 24.011948, RMSE: 4.900199, mean summed abs err: 651.639166
# Best prediction: 342, Worst prediction: 326
# UT VAL prediction diagnostics | collapse ratio: 0.0578 | RMSE: 4.9 | mean-curve RMSE: 4.633 | skill vs mean curve: -0.0577 | peak corr: 0.0138 | energy corr: 0.0892 | sample curve corr: 0.985
# UT VAL zones | elastic: collapse 0.145, RMSE 1.172 | peak_region: collapse 0.0434, RMSE 7.552 | post_peak: collapse 0.0775, RMSE 3.692
# [I 2026-05-14 19:02:54,729] Trial 0 finished with value: 0.37239496613984546 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.014520903042049865, 'mlp_head_dropout': 0.17323522915498704, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': None, 'loss_family': 'combined', 'mse_weight': 1.0, 'weighted_mse_weight': 0.5, 'derivative_weight': 0.05, 'peak_weight': 0.25, 'energy_weight': 0.1, 'peak_location_weight': 0.02, 'loss_reduction': 'mean', 'loss_derivative_order': 1, 'loss_SoftPeak_beta': 10.0, 'optimizer': 'adamw', 'lr': 0.00015788826347222452, 'weight_decay': 3.984190594434684e-06, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 10, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 0 with value: 0.37239496613984546.
#  -> Epoch 1/250 || LOSS - train: 0.271662, val: 0.094568 | MSE - train: 0.271662, val: 0.094568 | RMSE - train: 0.521212, val: 0.307519 | LR: 1.88e-04
# ================ Training Complete ================
#  Best Epoch: 5, with LOSS: 0.087252, MSE: 0.087252 and RMSE: 0.295385 ==================
# UT val metrics | MAE: 2.761321, MSE: 21.583412, RMSE: 4.645795, mean summed abs err: 555.025470
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.0645 | RMSE: 4.646 | mean-curve RMSE: 4.633 | skill vs mean curve: -0.00283 | peak corr: -0.0124 | energy corr: -0.0107 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.101, RMSE 1.157 | peak_region: collapse 0.058, RMSE 7.471 | post_peak: collapse 0.0743, RMSE 2.757
# [I 2026-05-14 19:05:02,550] Trial 1 finished with value: 0.29538532993362304 and parameters: {'mlp_act': 'mish', 'mlp_norm': 'layer', 'mlp_dropout': 0.08918833167339732, 'mlp_head_dropout': 0.05618690193747616, 'mlp_depth': 4, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00018760897310138582, 'weight_decay': 3.796166895800804e-08, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 1 with value: 0.29538532993362304.
#  -> Epoch 1/250 || LOSS - train: 0.624361, val: 0.246537 | MSE - train: 0.624361, val: 0.246537 | RMSE - train: 0.790165, val: 0.496525 | LR: 1.46e-04
# ================ Training Complete ================
#  Best Epoch: 8, with LOSS: 0.091328, MSE: 0.091328 and RMSE: 0.302205 ==================
# [I 2026-05-14 19:05:54,056] Trial 2 finished with value: 0.30220544283429984 and parameters: {'mlp_act': 'mish', 'mlp_norm': 'layer', 'mlp_dropout': 0.12344889909109769, 'mlp_head_dropout': 0.10454656587639882, 'mlp_depth': 2, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00014560262826662188, 'weight_decay': 6.398916399944068e-08, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 1 with value: 0.29538532993362304.
#  -> Epoch 1/250 || LOSS - train: 0.671913, val: 0.173026 | MSE - train: 0.671913, val: 0.173026 | RMSE - train: 0.819703, val: 0.415963 | LR: 3.13e-04
# ================ Training Complete ================
#  Best Epoch: 9, with LOSS: 0.092573, MSE: 0.092573 and RMSE: 0.304258 ==================
# [I 2026-05-14 19:06:25,988] Trial 3 finished with value: 0.304257963462122 and parameters: {'mlp_act': 'relu', 'mlp_norm': 'layer', 'mlp_dropout': 0.21518264581408586, 'mlp_head_dropout': 0.0013904261062381408, 'mlp_depth': 2, 'mlp_width': 256, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00031303431039358135, 'weight_decay': 3.194416563600358e-07, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 1 with value: 0.29538532993362304.
#  -> Epoch 1/250 || LOSS - train: 0.965287, val: 0.222494 | MSE - train: 0.965287, val: 0.222494 | RMSE - train: 0.982490, val: 0.471693 | LR: 5.40e-04
# ================ Training Complete ================
#  Best Epoch: 11, with LOSS: 0.092606, MSE: 0.092606 and RMSE: 0.304312 ==================
# [I 2026-05-14 19:07:02,855] Trial 4 finished with value: 0.3043117076922509 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'batch', 'mlp_dropout': 0.1820540871529649, 'mlp_head_dropout': 0.07355662654385065, 'mlp_depth': 3, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': None, 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0005402260463516798, 'weight_decay': 7.444441903453055e-08, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 1 with value: 0.29538532993362304.
#  -> Epoch 1/250 || LOSS - train: 1.043681, val: 0.430309 | MSE - train: 1.043681, val: 0.430309 | RMSE - train: 1.021607, val: 0.655979 | LR: 7.27e-05
# ================ Training Complete ================
#  Best Epoch: 31, with LOSS: 0.086805, MSE: 0.086805 and RMSE: 0.294627 ==================
# UT val metrics | MAE: 2.764719, MSE: 21.522114, RMSE: 4.639193, mean summed abs err: 555.708515
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.0512 | RMSE: 4.639 | mean-curve RMSE: 4.633 | skill vs mean curve: -0.00141 | peak corr: 0.0704 | energy corr: -0.0115 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.08, RMSE 1.152 | peak_region: collapse 0.0426, RMSE 7.462 | post_peak: collapse 0.0693, RMSE 2.748
# [I 2026-05-14 19:07:43,634] Trial 5 finished with value: 0.29462688323120884 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.2243039394883317, 'mlp_head_dropout': 0.1800836114326661, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 7.269984809673804e-05, 'weight_decay': 2.077346035713882e-05, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 5 with value: 0.29462688323120884.
#  -> Epoch 1/250 || LOSS - train: 0.285718, val: 0.095486 | MSE - train: 0.285718, val: 0.095486 | RMSE - train: 0.534526, val: 0.309008 | LR: 5.41e-04
# ================ Training Complete ================
#  Best Epoch: 3, with LOSS: 0.089451, MSE: 0.089451 and RMSE: 0.299084 ==================
# [I 2026-05-14 19:08:20,641] Trial 6 finished with value: 0.29908442133495333 and parameters: {'mlp_act': 'mish', 'mlp_norm': None, 'mlp_dropout': 0.09192895076485838, 'mlp_head_dropout': 0.05304047353634509, 'mlp_depth': 3, 'mlp_width': 256, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0005408232393627171, 'weight_decay': 7.68339918200298e-08, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 10, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 5 with value: 0.29462688323120884.
#  -> Epoch 1/250 || LOSS - train: 0.718000, val: 0.118710 | MSE - train: 0.718000, val: 0.118710 | RMSE - train: 0.847349, val: 0.344544 | LR: 9.90e-04
# ================ Training Complete ================
#  Best Epoch: 4, with LOSS: 0.089613, MSE: 0.089613 and RMSE: 0.299354 ==================
# [I 2026-05-14 19:08:50,581] Trial 7 finished with value: 0.29935436158871187 and parameters: {'mlp_act': 'relu', 'mlp_norm': None, 'mlp_dropout': 0.13920031561458754, 'mlp_head_dropout': 0.1872309548321562, 'mlp_depth': 2, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0009899542627616385, 'weight_decay': 0.00011234842109991873, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 5 with value: 0.29462688323120884.
#  -> Epoch 1/250 || LOSS - train: 0.892821, val: 0.555599 | MSE - train: 0.341150, val: 0.302406 | RMSE - train: 0.584081, val: 0.549915 | LR: 4.78e-04
# [I 2026-05-14 19:09:26,895] Trial 8 pruned.
#  -> Epoch 1/250 || LOSS - train: 0.155847, val: 0.104406 | MSE - train: 0.210684, val: 0.128990 | RMSE - train: 0.459003, val: 0.359151 | LR: 7.53e-04
# ================ Training Complete ================
#  Best Epoch: 3, with LOSS: 0.092561, MSE: 0.104962 and RMSE: 0.323978 ==================
# [I 2026-05-14 19:10:20,586] Trial 9 finished with value: 0.3239782567157241 and parameters: {'mlp_act': 'mish', 'mlp_norm': None, 'mlp_dropout': 0.09962618359934336, 'mlp_head_dropout': 0.1231700196104433, 'mlp_depth': 2, 'mlp_width': 256, 'mlp_block': 'mlp', 'mlp_head_norm': None, 'loss_family': 'combined', 'mse_weight': 1.0, 'weighted_mse_weight': 1.0, 'derivative_weight': 0.0, 'peak_weight': 0.5, 'energy_weight': 0.1, 'peak_location_weight': 0.0, 'loss_reduction': 'mean', 'loss_derivative_order': 1, 'loss_SoftPeak_beta': 40.0, 'optimizer': 'adamw', 'lr': 0.0007526584025742056, 'weight_decay': 0.00010408895582954854, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 10, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 5 with value: 0.29462688323120884.
#  -> Epoch 1/250 || LOSS - train: 2.510934, val: 1.730108 | MSE - train: 2.510934, val: 1.730108 | RMSE - train: 1.584593, val: 1.315336 | LR: 1.83e-04
# ================ Training Complete ================
#  Best Epoch: 38, with LOSS: 0.089748, MSE: 0.089748 and RMSE: 0.299580 ==================
# [I 2026-05-14 19:11:19,710] Trial 10 finished with value: 0.2995803080781491 and parameters: {'mlp_act': 'relu', 'mlp_norm': 'batch', 'mlp_dropout': 0.1991350410305987, 'mlp_head_dropout': 0.1849877825783053, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00018263772923697328, 'weight_decay': 2.346819715545846e-06, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 5 with value: 0.29462688323120884.
#  -> Epoch 1/250 || LOSS - train: 0.195847, val: 0.091075 | MSE - train: 0.195847, val: 0.091075 | RMSE - train: 0.442546, val: 0.301787 | LR: 3.34e-04
# ================ Training Complete ================
#  Best Epoch: 3, with LOSS: 0.087911, MSE: 0.087911 and RMSE: 0.296497 ==================
# [I 2026-05-14 19:13:41,508] Trial 11 finished with value: 0.2964972783245873 and parameters: {'mlp_act': 'mish', 'mlp_norm': 'layer', 'mlp_dropout': 0.050444826287052, 'mlp_head_dropout': 0.05611211242311703, 'mlp_depth': 4, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00033368772697492133, 'weight_decay': 1.9438589023565847e-06, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 5 with value: 0.29462688323120884.
#  -> Epoch 1/250 || LOSS - train: 0.716349, val: 0.098536 | MSE - train: 0.716349, val: 0.098536 | RMSE - train: 0.846374, val: 0.313904 | LR: 1.50e-04
# ================ Training Complete ================
#  Best Epoch: 16, with LOSS: 0.086621, MSE: 0.086621 and RMSE: 0.294315 ==================
# UT val metrics | MAE: 2.759988, MSE: 21.490777, RMSE: 4.635815, mean summed abs err: 554.757682
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.0298 | RMSE: 4.636 | mean-curve RMSE: 4.633 | skill vs mean curve: -0.000678 | peak corr: 0.011 | energy corr: 0.0131 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.0473, RMSE 1.154 | peak_region: collapse 0.0234, RMSE 7.457 | post_peak: collapse 0.0443, RMSE 2.745
# [I 2026-05-14 19:14:34,989] Trial 12 finished with value: 0.2943149918571209 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.24745495151497893, 'mlp_head_dropout': 0.1294620145809347, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00015033698530544226, 'weight_decay': 1.5154288724774007e-06, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 12 with value: 0.2943149918571209.
#  -> Epoch 1/250 || LOSS - train: 0.584149, val: 0.097023 | MSE - train: 0.584149, val: 0.097023 | RMSE - train: 0.764296, val: 0.311485 | LR: 1.45e-04
# ================ Training Complete ================
#  Best Epoch: 11, with LOSS: 0.086687, MSE: 0.086687 and RMSE: 0.294427 ==================
# [I 2026-05-14 19:15:21,706] Trial 13 finished with value: 0.29442733046094954 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.21114124746773358, 'mlp_head_dropout': 0.08602368001352366, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0001453253342771894, 'weight_decay': 2.8692399475692694e-06, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 12 with value: 0.2943149918571209.
#  -> Epoch 1/250 || LOSS - train: 0.613311, val: 0.097584 | MSE - train: 0.613311, val: 0.097584 | RMSE - train: 0.783142, val: 0.312385 | LR: 5.91e-05
# ================ Training Complete ================
#  Best Epoch: 10, with LOSS: 0.086575, MSE: 0.086575 and RMSE: 0.294236 ==================
# UT val metrics | MAE: 2.759440, MSE: 21.450338, RMSE: 4.631451, mean summed abs err: 554.647423
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.0388 | RMSE: 4.631 | mean-curve RMSE: 4.633 | skill vs mean curve: 0.000264 | peak corr: -0.121 | energy corr: 0.0823 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.0557, RMSE 1.155 | peak_region: collapse 0.0329, RMSE 7.45 | post_peak: collapse 0.052, RMSE 2.742
# [I 2026-05-14 19:17:42,855] Trial 14 finished with value: 0.2942359864463054 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.2054741637241686, 'mlp_head_dropout': 0.12276855008664725, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 5.909526192221812e-05, 'weight_decay': 1.1377144113812162e-07, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 0.430708, val: 0.090763 | MSE - train: 0.430708, val: 0.090763 | RMSE - train: 0.656284, val: 0.301270 | LR: 5.49e-05
# ================ Training Complete ================
#  Best Epoch: 12, with LOSS: 0.086583, MSE: 0.086583 and RMSE: 0.294249 ==================
# [I 2026-05-14 19:22:27,483] Trial 15 finished with value: 0.29424933891915855 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.11706447638890162, 'mlp_head_dropout': 0.05412245094198616, 'mlp_depth': 3, 'mlp_width': 512, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 5.492890196219933e-05, 'weight_decay': 2.3456456861544816e-07, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 0.373608, val: 0.089319 | MSE - train: 0.373608, val: 0.089319 | RMSE - train: 0.611235, val: 0.298863 | LR: 8.96e-05
# ================ Training Complete ================
#  Best Epoch: 7, with LOSS: 0.086718, MSE: 0.086718 and RMSE: 0.294480 ==================
# [I 2026-05-14 19:27:58,584] Trial 16 finished with value: 0.29447991773260496 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.05693717259155351, 'mlp_head_dropout': 0.1112416636503722, 'mlp_depth': 4, 'mlp_width': 512, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 8.956464103824378e-05, 'weight_decay': 1.1704578929343092e-07, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 1.110738, val: 0.908477 | MSE - train: 1.110738, val: 0.908477 | RMSE - train: 1.053915, val: 0.953140 | LR: 5.14e-05
# [I 2026-05-14 19:29:26,088] Trial 17 pruned.
#  -> Epoch 1/250 || LOSS - train: 0.265126, val: 0.128977 | MSE - train: 0.265126, val: 0.128977 | RMSE - train: 0.514904, val: 0.359133 | LR: 7.58e-05
# ================ Training Complete ================
#  Best Epoch: 4, with LOSS: 0.091478, MSE: 0.091478 and RMSE: 0.302454 ==================
# [I 2026-05-14 19:31:05,295] Trial 18 finished with value: 0.3024539565908693 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.0940299952872005, 'mlp_head_dropout': 0.06090365924528757, 'mlp_depth': 3, 'mlp_width': 256, 'mlp_block': 'res', 'mlp_head_norm': None, 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 7.58139578823652e-05, 'weight_decay': 1.904676346001664e-06, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 150.775441, val: 3.627336 | MSE - train: 0.741449, val: 0.372395 | RMSE - train: 0.861074, val: 0.610241 | LR: 8.47e-05
# [I 2026-05-14 19:33:30,874] Trial 19 pruned.
#  -> Epoch 1/250 || LOSS - train: 767.400905, val: 20.572651 | MSE - train: 0.724900, val: 0.369603 | RMSE - train: 0.851411, val: 0.607950 | LR: 8.62e-05
# [I 2026-05-14 19:37:00,519] Trial 20 pruned.
#  -> Epoch 1/250 || LOSS - train: 0.860607, val: 0.197117 | MSE - train: 0.860607, val: 0.197117 | RMSE - train: 0.927689, val: 0.443979 | LR: 1.16e-04
# ================ Training Complete ================
#  Best Epoch: 9, with LOSS: 0.091603, MSE: 0.091603 and RMSE: 0.302660 ==================
# [I 2026-05-14 19:38:39,034] Trial 21 finished with value: 0.3026601352095532 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.232212522434525, 'mlp_head_dropout': 0.16188179106646372, 'mlp_depth': 2, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00011575214195726704, 'weight_decay': 6.247058656875192e-08, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 0.973119, val: 0.156346 | MSE - train: 0.973119, val: 0.156346 | RMSE - train: 0.986468, val: 0.395407 | LR: 5.88e-05
# ================ Training Complete ================
#  Best Epoch: 14, with LOSS: 0.086803, MSE: 0.086803 and RMSE: 0.294624 ==================
# [I 2026-05-14 19:39:56,359] Trial 22 finished with value: 0.2946239379198228 and parameters: {'mlp_act': 'mish', 'mlp_norm': None, 'mlp_dropout': 0.21029450377553016, 'mlp_head_dropout': 0.13843905939202236, 'mlp_depth': 4, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 5.880466071013146e-05, 'weight_decay': 2.178408071121155e-07, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 1.011255, val: 0.240409 | MSE - train: 1.011255, val: 0.240409 | RMSE - train: 1.005612, val: 0.490315 | LR: 5.00e-05
# ================ Training Complete ================
#  Best Epoch: 14, with LOSS: 0.087431, MSE: 0.087431 and RMSE: 0.295687 ==================
# [I 2026-05-14 19:42:02,897] Trial 23 finished with value: 0.29568704184800565 and parameters: {'mlp_act': 'mish', 'mlp_norm': None, 'mlp_dropout': 0.20058496750918944, 'mlp_head_dropout': 0.11802809793015516, 'mlp_depth': 3, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 5.0040109039104116e-05, 'weight_decay': 8.082607624023858e-08, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 0.535988, val: 0.094906 | MSE - train: 0.535988, val: 0.094906 | RMSE - train: 0.732112, val: 0.308068 | LR: 8.86e-05
# ================ Training Complete ================
#  Best Epoch: 21, with LOSS: 0.086636, MSE: 0.086636 and RMSE: 0.294341 ==================
# [I 2026-05-14 19:43:58,791] Trial 24 finished with value: 0.29434070248782107 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.07090931153627032, 'mlp_head_dropout': 0.030672827171141778, 'mlp_depth': 3, 'mlp_width': 512, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 8.86262674038402e-05, 'weight_decay': 3.50409605919253e-08, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 0.534316, val: 0.115434 | MSE - train: 0.534316, val: 0.115434 | RMSE - train: 0.730969, val: 0.339756 | LR: 6.55e-05
# ================ Training Complete ================
#  Best Epoch: 12, with LOSS: 0.086669, MSE: 0.086669 and RMSE: 0.294396 ==================
# [I 2026-05-14 19:45:05,006] Trial 25 finished with value: 0.2943961973633109 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.1674836553476843, 'mlp_head_dropout': 0.0832918652605803, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 6.547906016991083e-05, 'weight_decay': 5.5753931449342474e-08, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 10, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 14 with value: 0.2942359864463054.
#  -> Epoch 1/250 || LOSS - train: 1.598964, val: 0.867116 | MSE - train: 1.598964, val: 0.867116 | RMSE - train: 1.264501, val: 0.931191 | LR: 1.02e-04
# [I 2026-05-14 19:47:38,527] Trial 26 pruned.
#  -> Epoch 1/250 || LOSS - train: 0.600063, val: 0.091934 | MSE - train: 0.600063, val: 0.091934 | RMSE - train: 0.774638, val: 0.303206 | LR: 1.87e-04
# ================ Training Complete ================
#  Best Epoch: 17, with LOSS: 0.086470, MSE: 0.086470 and RMSE: 0.294057 ==================
# UT val metrics | MAE: 2.758520, MSE: 21.468911, RMSE: 4.633456, mean summed abs err: 554.462519
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.0151 | RMSE: 4.633 | mean-curve RMSE: 4.633 | skill vs mean curve: -0.000169 | peak corr: 0.0795 | energy corr: -0.0162 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.0253, RMSE 1.152 | peak_region: collapse 0.0132, RMSE 7.454 | post_peak: collapse 0.0183, RMSE 2.743
# [I 2026-05-14 19:49:03,106] Trial 27 finished with value: 0.2940571802224709 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.23030318571682504, 'mlp_head_dropout': 0.13729283492627165, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00018696830184132223, 'weight_decay': 4.2395456646738195e-07, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 27 with value: 0.2940571802224709.
#  -> Epoch 1/250 || LOSS - train: 1530.872113, val: 35.072498 | MSE - train: 1.113046, val: 0.458795 | RMSE - train: 1.055010, val: 0.677344 | LR: 1.30e-04
# [I 2026-05-14 19:53:49,954] Trial 28 pruned.
#  -> Epoch 1/250 || LOSS - train: 0.505691, val: 0.090144 | MSE - train: 0.505691, val: 0.090144 | RMSE - train: 0.711119, val: 0.300239 | LR: 3.31e-04
# ================ Training Complete ================
#  Best Epoch: 7, with LOSS: 0.086750, MSE: 0.086750 and RMSE: 0.294534 ==================
# [I 2026-05-14 19:55:11,195] Trial 29 finished with value: 0.2945335071376342 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.1831383426703431, 'mlp_head_dropout': 0.15690686859148872, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00033147310701014395, 'weight_decay': 3.844159660319282e-07, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 27 with value: 0.2940571802224709.
#  -> Epoch 1/250 || LOSS - train: 582.016760, val: 4.134917 | MSE - train: 0.923925, val: 0.395626 | RMSE - train: 0.961210, val: 0.628988 | LR: 5.24e-05
# [I 2026-05-14 20:12:29,389] Trial 30 pruned.
#  -> Epoch 1/250 || LOSS - train: 0.469319, val: 0.094303 | MSE - train: 0.469319, val: 0.094303 | RMSE - train: 0.685069, val: 0.307088 | LR: 7.27e-05
# ================ Training Complete ================
#  Best Epoch: 6, with LOSS: 0.087047, MSE: 0.087047 and RMSE: 0.295037 ==================
# [I 2026-05-14 20:14:57,670] Trial 31 finished with value: 0.2950372286172421 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.18172319581550359, 'mlp_head_dropout': 0.09504286341104196, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 7.266823228638952e-05, 'weight_decay': 2.6347618021422938e-08, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 27 with value: 0.2940571802224709.
#  -> Epoch 1/250 || LOSS - train: 0.272532, val: 0.090093 | MSE - train: 0.272532, val: 0.090093 | RMSE - train: 0.522046, val: 0.300155 | LR: 5.87e-05
# ================ Training Complete ================
#  Best Epoch: 14, with LOSS: 0.086760, MSE: 0.086760 and RMSE: 0.294550 ==================
# [I 2026-05-14 20:23:10,004] Trial 32 finished with value: 0.2945500074977635 and parameters: {'mlp_act': 'relu', 'mlp_norm': None, 'mlp_dropout': 0.19175206476119086, 'mlp_head_dropout': 0.00848868031450388, 'mlp_depth': 3, 'mlp_width': 512, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 5.8731138416539654e-05, 'weight_decay': 5.768029285502965e-06, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 27 with value: 0.2940571802224709.
#  -> Epoch 1/250 || LOSS - train: 1.883768, val: 1.067899 | MSE - train: 1.883768, val: 1.067899 | RMSE - train: 1.372504, val: 1.033392 | LR: 9.70e-05
# [I 2026-05-14 20:24:43,224] Trial 33 pruned.
#  -> Epoch 1/250 || LOSS - train: 0.431010, val: 0.127726 | MSE - train: 0.431010, val: 0.127726 | RMSE - train: 0.656513, val: 0.357388 | LR: 5.98e-05
# ================ Training Complete ================
#  Best Epoch: 11, with LOSS: 0.087453, MSE: 0.087453 and RMSE: 0.295725 ==================
# [I 2026-05-14 20:26:23,594] Trial 34 finished with value: 0.2957248411369921 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.09514905132572571, 'mlp_head_dropout': 0.018962871485151904, 'mlp_depth': 3, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 5.9782717109246046e-05, 'weight_decay': 3.87371362387253e-07, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 10, 'early_stop': True, 'early_stop_patience': 30}. Best is trial 27 with value: 0.2940571802224709.
#  -> Epoch 1/250 || LOSS - train: 666.986809, val: 11.786210 | MSE - train: 0.931176, val: 0.316975 | RMSE - train: 0.964975, val: 0.563005 | LR: 7.17e-05
#  -> Epoch 250/250 || LOSS - train: 0.865086, val: 0.867967 | MSE - train: 0.106281, val: 0.088966 | RMSE - train: 0.326008, val: 0.298271 | LR: 1.74e-07
# ================ Training Complete ================
#  Best Epoch: 220, with LOSS: 0.867958, MSE: 0.088972 and RMSE: 0.298282 ==================
# [I 2026-05-14 20:43:39,509] Trial 35 finished with value: 0.2982823447998289 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.09411189170936829, 'mlp_head_dropout': 0.10098029749841797, 'mlp_depth': 3, 'mlp_width': 512, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'combined', 'mse_weight': 0.5, 'weighted_mse_weight': 1.0, 'derivative_weight': 0.05, 'peak_weight': 0.0, 'energy_weight': 0.0, 'peak_location_weight': 0.0, 'loss_reduction': 'mean', 'loss_derivative_order': 1, 'loss_SoftPeak_beta': 10.0, 'optimizer': 'adamw', 'lr': 7.173682843090832e-05, 'weight_decay': 3.3256782953125174e-06, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 27 with value: 0.2940571802224709.
#  -> Epoch 1/250 || LOSS - train: 0.348450, val: 0.091053 | MSE - train: 0.348450, val: 0.091053 | RMSE - train: 0.590297, val: 0.301750 | LR: 1.55e-04
# ================ Training Complete ================
#  Best Epoch: 5, with LOSS: 0.087053, MSE: 0.087053 and RMSE: 0.295048 ==================
# [I 2026-05-14 20:46:47,024] Trial 36 finished with value: 0.2950480169753401 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.22037230960588897, 'mlp_head_dropout': 0.07553873984449717, 'mlp_depth': 4, 'mlp_width': 512, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0001549502304933899, 'weight_decay': 2.7397531016627956e-07, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 10, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 27 with value: 0.2940571802224709.
#  -> Epoch 1/250 || LOSS - train: 0.541636, val: 0.113504 | MSE - train: 0.541636, val: 0.113504 | RMSE - train: 0.735959, val: 0.336903 | LR: 1.05e-04
# ================ Training Complete ================
#  Best Epoch: 23, with LOSS: 0.086384, MSE: 0.086384 and RMSE: 0.293912 ==================
# UT val metrics | MAE: 2.750544, MSE: 21.451343, RMSE: 4.631559, mean summed abs err: 552.859390
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.0158 | RMSE: 4.632 | mean-curve RMSE: 4.633 | skill vs mean curve: 0.000241 | peak corr: -0.0224 | energy corr: 0.0755 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.0228, RMSE 1.152 | peak_region: collapse 0.0136, RMSE 7.451 | post_peak: collapse 0.0208, RMSE 2.741
# [I 2026-05-14 20:47:59,976] Trial 37 finished with value: 0.2939122245402512 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.20660264515420326, 'mlp_head_dropout': 0.0718840092620335, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00010477660675899629, 'weight_decay': 1.1314033659182521e-07, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.394593, val: 0.093477 | MSE - train: 0.394593, val: 0.093477 | RMSE - train: 0.628167, val: 0.305741 | LR: 1.73e-04
# ================ Training Complete ================
#  Best Epoch: 16, with LOSS: 0.086510, MSE: 0.086510 and RMSE: 0.294126 ==================
# [I 2026-05-14 20:49:07,330] Trial 38 finished with value: 0.2941263644867807 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.1541036346284671, 'mlp_head_dropout': 0.07143230843222002, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00017261530990071096, 'weight_decay': 1.2927341536499245e-08, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.330301, val: 0.090408 | MSE - train: 0.330301, val: 0.090408 | RMSE - train: 0.574719, val: 0.300680 | LR: 2.54e-04
# ================ Training Complete ================
#  Best Epoch: 11, with LOSS: 0.086541, MSE: 0.086541 and RMSE: 0.294178 ==================
# [I 2026-05-14 20:50:14,361] Trial 39 finished with value: 0.2941779497045419 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.14943159314316778, 'mlp_head_dropout': 0.0791644538259194, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0002542641971785238, 'weight_decay': 2.884658649796973e-08, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.400641, val: 0.094792 | MSE - train: 0.400641, val: 0.094792 | RMSE - train: 0.632962, val: 0.307883 | LR: 1.93e-04
# ================ Training Complete ================
#  Best Epoch: 14, with LOSS: 0.086476, MSE: 0.086476 and RMSE: 0.294067 ==================
# [I 2026-05-14 20:51:22,723] Trial 40 finished with value: 0.2940673230794925 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.165648192440202, 'mlp_head_dropout': 0.06612554855205977, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0001934153051882412, 'weight_decay': 5.605726508130084e-08, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.872437, val: 0.385284 | MSE - train: 0.872437, val: 0.385284 | RMSE - train: 0.934043, val: 0.620712 | LR: 2.62e-04
# ================ Training Complete ================
#  Best Epoch: 10, with LOSS: 0.089179, MSE: 0.089179 and RMSE: 0.298628 ==================
# [I 2026-05-14 20:52:43,130] Trial 41 finished with value: 0.29862806697957467 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'batch', 'mlp_dropout': 0.1757058422211033, 'mlp_head_dropout': 0.07938117027082538, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'mlp', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0002619192968045168, 'weight_decay': 1.3355406721501675e-08, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.608209, val: 0.124561 | MSE - train: 0.608209, val: 0.124561 | RMSE - train: 0.779878, val: 0.352931 | LR: 8.57e-05
# ================ Training Complete ================
#  Best Epoch: 19, with LOSS: 0.086455, MSE: 0.086455 and RMSE: 0.294032 ==================
# [I 2026-05-14 20:54:50,073] Trial 42 finished with value: 0.29403227620186473 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.16970650884891705, 'mlp_head_dropout': 0.09147542196738992, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 8.569731845935469e-05, 'weight_decay': 4.865600381423201e-06, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 1.584747, val: 0.251096 | MSE - train: 1.584747, val: 0.251096 | RMSE - train: 1.258867, val: 0.501095 | LR: 8.27e-05
# ================ Training Complete ================
#  Best Epoch: 31, with LOSS: 0.086642, MSE: 0.086642 and RMSE: 0.294350 ==================
# [I 2026-05-14 20:57:02,005] Trial 43 finished with value: 0.2943504663405366 and parameters: {'mlp_act': 'relu', 'mlp_norm': 'layer', 'mlp_dropout': 0.18290306290283798, 'mlp_head_dropout': 0.12984076317135143, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 8.267527015240467e-05, 'weight_decay': 5.705428462328674e-05, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 1.039494, val: 0.180575 | MSE - train: 1.039494, val: 0.180575 | RMSE - train: 1.019556, val: 0.424942 | LR: 1.52e-04
# ================ Training Complete ================
#  Best Epoch: 13, with LOSS: 0.088077, MSE: 0.088077 and RMSE: 0.296778 ==================
# [I 2026-05-14 20:58:53,358] Trial 44 finished with value: 0.2967776253510427 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.11041674124629056, 'mlp_head_dropout': 0.06687617227780401, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': None, 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0001521654948004179, 'weight_decay': 4.866053873183464e-06, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.716309, val: 0.167908 | MSE - train: 0.716309, val: 0.167908 | RMSE - train: 0.846350, val: 0.409766 | LR: 6.24e-05
# ================ Training Complete ================
#  Best Epoch: 20, with LOSS: 0.086707, MSE: 0.086707 and RMSE: 0.294461 ==================
# [I 2026-05-14 21:01:03,140] Trial 45 finished with value: 0.29446091039704025 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'layer', 'mlp_dropout': 0.1779940103568403, 'mlp_head_dropout': 0.14079728714139284, 'mlp_depth': 4, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 6.241956414051618e-05, 'weight_decay': 1.9413934491966207e-07, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.467987, val: 0.087995 | MSE - train: 0.467987, val: 0.087995 | RMSE - train: 0.684096, val: 0.296639 | LR: 8.35e-05
# ================ Training Complete ================
#  Best Epoch: 28, with LOSS: 0.086501, MSE: 0.086501 and RMSE: 0.294111 ==================
# [I 2026-05-14 21:08:27,029] Trial 46 finished with value: 0.29411087235522626 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.23073687021577213, 'mlp_head_dropout': 0.05499192221447033, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 8.353838695794946e-05, 'weight_decay': 3.557830732398168e-07, 'batch': 32, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.606287, val: 0.088504 | MSE - train: 0.606287, val: 0.088504 | RMSE - train: 0.778644, val: 0.297496 | LR: 8.47e-05
# ================ Training Complete ================
#  Best Epoch: 64, with LOSS: 0.086405, MSE: 0.086405 and RMSE: 0.293947 ==================
# [I 2026-05-14 21:14:10,727] Trial 47 finished with value: 0.29394699326043194 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.23788556873090144, 'mlp_head_dropout': 0.03578120185468095, 'mlp_depth': 5, 'mlp_width': 512, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 8.465225836628655e-05, 'weight_decay': 1.089061467762146e-05, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 1.060061, val: 0.793642 | MSE - train: 1.060061, val: 0.793642 | RMSE - train: 1.029593, val: 0.890866 | LR: 8.78e-05
# ================ Training Complete ================
#  Best Epoch: 27, with LOSS: 0.095444, MSE: 0.095444 and RMSE: 0.308940 ==================
# [I 2026-05-14 21:15:52,426] Trial 48 finished with value: 0.3089400829527899 and parameters: {'mlp_act': 'gelu', 'mlp_norm': 'batch', 'mlp_dropout': 0.23191241213571803, 'mlp_head_dropout': 0.00936264821247159, 'mlp_depth': 5, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 8.777543883306259e-05, 'weight_decay': 9.347527324538155e-07, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 10, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#  -> Epoch 1/250 || LOSS - train: 0.862371, val: 0.368920 | MSE - train: 0.862371, val: 0.368920 | RMSE - train: 0.928639, val: 0.607388 | LR: 1.09e-04
# ================ Training Complete ================
#  Best Epoch: 31, with LOSS: 0.086504, MSE: 0.086504 and RMSE: 0.294115 ==================
# [I 2026-05-14 21:16:37,510] Trial 49 finished with value: 0.29411497206086357 and parameters: {'mlp_act': 'gelu', 'mlp_norm': None, 'mlp_dropout': 0.20691347449908862, 'mlp_head_dropout': 0.041181057729131006, 'mlp_depth': 2, 'mlp_width': 128, 'mlp_block': 'res', 'mlp_head_norm': 'layer', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00010876244576639005, 'weight_decay': 0.00040223295710975244, 'batch': 64, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 20, 'early_stop': True, 'early_stop_patience': 50}. Best is trial 37 with value: 0.2939122245402512.
#
# ==================================================
#  Optimization Finished. Study statistics:
#   Number of finished trials: 50
#
# Best trial
#  Objective (rmse): 0.2939122245402512
#
#  Hyperparameters:
#   mlp_act: gelu
#   mlp_norm: layer
#   mlp_dropout: 0.20660264515420326
#   mlp_head_dropout: 0.0718840092620335
#   mlp_depth: 5
#   mlp_width: 128
#   mlp_block: mlp
#   mlp_head_norm: layer
#   loss_family: mse
#   optimizer: adamw
#   lr: 0.00010477660675899629
#   weight_decay: 1.1314033659182521e-07
#   batch: 32
#   objective_metric: rmse
#   w_init: auto
#   scheduler: plateau
#   scheduler_factor: 0.5
#   scheduler_patience: 20
#   early_stop: True
#   early_stop_patience: 50
# {'best_value': 0.2939122245402512,
#  'best_params': {'mlp_act': 'gelu',
#   'mlp_norm': 'layer',
#   'mlp_dropout': 0.20660264515420326,
#   'mlp_head_dropout': 0.0718840092620335,
#   'mlp_depth': 5,
#   'mlp_width': 128,
#   'mlp_block': 'mlp',
#   'mlp_head_norm': 'layer',
#   'loss_family': 'mse',
#   'optimizer': 'adamw',
#   'lr': 0.00010477660675899629,
#   'weight_decay': 1.1314033659182521e-07,
#   'batch': 32,
#   'objective_metric': 'rmse',
#   'w_init': 'auto',
#   'scheduler': 'plateau',
#   'scheduler_factor': 0.5,
#   'scheduler_patience': 20,
#   'early_stop': True,
#   'early_stop_patience': 50},
#  'best_user_attrs': {'best_model_checkpoint': 'Z:\\p2\\UT\\MLP\\HPO\\MLP_full_hOpt\\best_model.mdl',
#   'loss_params': {'family': 'mse'},
#   'model_params': {'in_size': 1444,
#    'out_size': 201,
#    'h_size': [128, 128, 128, 128, 128],
#    'act': 'gelu',
#    'block': 'mlp',
#    'norm': 'layer',
#    'dropout': 0.20660264515420326,
#    'head_norm': 'layer',
#    'head_dropout': 0.0718840092620335},
#   'task_scores': [0.2939122245402512],
#   'train_params': {'lr': 0.00010477660675899629,
#    'weight_decay': 1.1314033659182521e-07,
#    'opt_name': 'adamw',
#    'batch': 32,
#    'n_epochs': 250,
#    'verbose': 0,
#    'metric': 'rmse',
#    'w_init': 'auto',
#    'scheduler': ['plateau', 'min', 0.5, 20, 0.0001]},
#   'typ': 'mlp'}}

# %% [markdown]
# ### MODEL

# %%
MLP1 = MODEL(
    typ=DAT.model,
    model=MLP(in_size=DAT.UT_train_in.shape[-1], 
              h_size=[4096, 2048, 1024, 1024, 1024, 512, 512], 
              out_size=DAT.UT_train_out.shape[-1], 
              act="relu",
              block="mlp",
              norm="batch", 
              dropout=0.0).to(device), 
    lossf=QuantileLossMATLAB(quantiles=[0.5, 0.45, 0.1], zone_boundaries=(65, 130), err_type="L2"),
    opt=("adam", 6.016e-6), #("adam", 1e-4),
    batch=32,
    lr=9e-4,
    data=DAT,
    mechMode=DAT.mechMode,
    scheduler=("min", 0.2427, 100, 1e-4), #("min", 0.2427, 18, 1e-4), 
    earlyStop=EarlyStopping(patience=500, min_delta=1e-4, verbose=True),
    w_init="auto",
    device=device,
    optTrial=None,
    scan_matches_on_init=True
)

MLP1.summary()

# %%
MLP1.train(n_epochs=1000, verbose=20, plot=True)

# %%
MLP1.save(path=None, name=None)

# %%
MLP1.predict(test_dataloader=None, plot=True)

# %%
for i in range(len(MLP1.UT_test_outputs)):
    plot_predictions(DAT.UT_OUT_df, MLP1.UT_test_outputs, MLP1.UT_truth, indx=i, d_out=False)

# %% [markdown]
# ## Graph Neural Network (GNN)

# %% [markdown]
# ### DATA

# %%
DAT_GNN = DATA(
    path=1, 
    path_add="",
    load=True, 
    load_split=False,
    split_frac=0.9,
    split_seed=42,
    range_split=(True, False),
    save_split=False,
    LAT="FCC", 
    dis="disNodes", 
    dN=0.2,
    d_data="in",
    mechMode="UT",
    nsims=None,
    model="GNN",
    scale=("symm", "inout"),
    reduce_dim=False, #("PCA", "out", 0.95, 10, True)
    round_decimals=5,
    geom_feats=(True, True),
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
DAT = DAT_GNN
if DAT.UTmechTest:
    print("UT shape:", DAT.UT_train_in.shape, DAT.UT_train_out.shape)
    print("Train -  in (min, max):", DAT.UT_train_in.min(), DAT.UT_train_in.max(), "\n        out (min, max):", DAT.UT_train_out.min(), DAT.UT_train_out.max())
    print("  Val -  in (min, max):", DAT.UT_val_in.min(), DAT.UT_val_in.max(), "\n        out (min, max):", DAT.UT_val_out.min(), DAT.UT_val_out.max())
    print(" Test -  in (min, max):", DAT.UT_test_in.min(), DAT.UT_test_in.max(), "\n        out (min, max):", DAT.UT_test_out.min(), DAT.UT_test_out.max())
    if DAT.FTmechTest: print("\n========================================================\n")
if DAT.FTmechTest:
    print("FT shape:", DAT.FT_train_in.shape, DAT.FT_train_out.shape)
    print("Train -  in (min, max):", DAT.FT_train_in.min(), DAT.FT_train_in.max(), "\n        out (min, max):", DAT.FT_train_out.min(), DAT.FT_train_out.max())
    print("  Val -  in (min, max):", DAT.FT_val_in.min(), DAT.FT_val_in.max(), "\n        out (min, max):", DAT.FT_val_out.min(), DAT.FT_val_out.max())
    print(" Test -  in (min, max):", DAT.FT_test_in.min(), DAT.FT_test_in.max(), "\n        out (min, max):", DAT.FT_test_out.min(), DAT.FT_test_out.max())
# Out:
# UT shape: (5561, 800, 8) (5561, 201)
# Train -  in (min, max): -1.0 1.0
#         out (min, max): -1.0 1.0
#   Val -  in (min, max): -1.0 1.0
#         out (min, max): -1.6191947669483455 1.103937947512592
#  Test -  in (min, max): -1.0 1.0
#         out (min, max): -1.595077081066206 1.0862485225493743

# %% [markdown]
# ### HPO

# %%
# HYPERPARAMETER OPTIMIZATION HERE.
# Full GCN/GAT HPO run on the full graph DATA split. Re-running resumes the saved Optuna studies.

GNN_hOpt_model_space = {
    "gcn": {
        "depth": [2, 3, 4],
        "width": [64, 128, 256],
        "act": ["relu", "gelu", "mish"],
        "norm": [None, "layer"],
        "dropout": {"type": "float", "low": 0.0, "high": 0.25},
        "head_norm": [None, "layer"],
        "head_dropout": {"type": "float", "low": 0.0, "high": 0.20},
        "pool": ["mean"],
    },
    "gat": {
        "depth": [1, 2, 3],
        "width": [32, 64, 128],
        "heads": [1, 2, 4],
        "act": ["relu", "gelu"],
        "norm": [None, "layer"],
        "dropout": {"type": "float", "low": 0.0, "high": 0.25},
        "att_dropout": {"type": "float", "low": 0.0, "high": 0.20},
        "head_norm": [None, "layer"],
        "head_dropout": {"type": "float", "low": 0.0, "high": 0.20},
        "pool": ["mean"],
    },
}

GNN_hOpt_loss_space = {
    "family": ["mse", "combined"],
    "mse_weight": [0.25, 0.5, 1.0],
    "weighted_mse_weight": [0.0, 0.5, 1.0, 2.0],
    "derivative_weight": [0.0, 0.02, 0.05, 0.10],
    "peak_weight": [0.0, 0.10, 0.25, 0.50],
    "energy_weight": [0.0, 0.05, 0.10, 0.25],
    "peak_location_weight": [0.0, 0.02, 0.05],
    "reduction": ["mean"],
    "derivative_order": [1],
    "SoftPeak_beta": [10.0, 20.0, 40.0],
    "UT": {
        "zone_boundaries": (65, 130),
        "zone_weights": (1.0, 5.0, 0.2),
    },
    "FT": {
        "zone_boundaries": (85, 160),
        "zone_weights": (1.0, 5.0, 0.2),
    },
}

GNN_hOpt_train_space = {
    "optimizer": ["adamw"],
    "lr": {"type": "float", "low": 3e-5, "high": 1e-3, "log": True},
    "weight_decay": {"type": "float", "low": 1e-8, "high": 1e-3, "log": True},
    "batch": [4, 8, 16],
    "n_epochs": {"type": "fixed", "value": 150},
    "metric": ["rmse"],
    "scheduler": ["plateau"],
    "scheduler_factor": [0.3, 0.5],
    "scheduler_patience": [8, 15],
    "scheduler_threshold": {"type": "fixed", "value": 1e-4},
    "early_stop": [True],
    "early_stop_patience": [25, 40],
    "early_stop_min_delta": {"type": "fixed", "value": 1e-5},
    "verbose": {"type": "fixed", "value": 0},
}

studies_GNN_full = hOpt_compare(
    typs=["gcn", "gat"],
    data=DAT_GNN,
    n_trials_per_typ=30,
    model_space=GNN_hOpt_model_space,
    loss_space=GNN_hOpt_loss_space,
    train_space=GNN_hOpt_train_space,
    seed=42,
    device=device,
    save=True,
    save_best_model=True,
    name="GNN_full_hOpt",
    n_jobs=1,
    show_progress_bar=True,
)

hOpt_best_summary(studies_GNN_full)
# Out:
# c:\Users\exy053\Documents\00-PhD-gitRepo\.venv311\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# c:\Users\exy053\Documents\00-PhD-gitRepo\.venv311\Lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``group`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# C:\Users\exy053\Documents\00-PhD-gitRepo\resources\MLfunc.py:2200: ExperimentalWarning: PatientPruner is experimental (supported from v2.8.0). The interface can change in the future.
#   pruner = optuna.pruners.PatientPruner(base_pruner, patience=5) if hasattr(optuna.pruners, "PatientPruner") else base_pruner
# [I 2026-05-14 21:16:44,660] A new study created in RDB with name: GNN_full_hOpt_GCN
#   0%|          | 0/30 [00:00<?, ?it/s]
#  -> Epoch 1/150 || LOSS - train: 0.115582, val: 0.107578 | MSE - train: 0.098734, val: 0.090497 | RMSE - train: 0.314219, val: 0.300827 | LR: 7.28e-04
# ================ Training Complete ================
#  Best Epoch: 41, with LOSS: 0.104151, MSE: 0.086553 and RMSE: 0.294200 ==================
# UT val metrics | MAE: 2.769332, MSE: 21.549775, RMSE: 4.642173, mean summed abs err: 556.635828
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.0118 | RMSE: 4.642 | mean-curve RMSE: 4.633 | skill vs mean curve: -0.00205 | peak corr: 0.0219 | energy corr: -0.0381 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.0355, RMSE 1.151 | peak_region: collapse 0.0108, RMSE 7.47 | post_peak: collapse 0.00836, RMSE 2.742
# [I 2026-05-14 21:41:51,418] Trial 0 finished with value: 0.2941995522050218 and parameters: {'gcn_act': 'gelu', 'gcn_norm': None, 'gcn_dropout': 0.03899863008405066, 'gcn_head_dropout': 0.011616722433639893, 'gcn_depth': 2, 'gcn_width': 128, 'gcn_att_dropout': 0.07431868873739665, 'gcn_head_norm': 'layer', 'gcn_pool': 'mean', 'loss_family': 'combined', 'mse_weight': 1.0, 'weighted_mse_weight': 2.0, 'derivative_weight': 0.0, 'peak_weight': 0.1, 'energy_weight': 0.05, 'peak_location_weight': 0.02, 'loss_reduction': 'mean', 'loss_derivative_order': 1, 'loss_SoftPeak_beta': 20.0, 'optimizer': 'adamw', 'lr': 0.000727622244615796, 'weight_decay': 1.9674328025306071e-07, 'batch': 4, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 8, 'early_stop': True, 'early_stop_patience': 25}. Best is trial 0 with value: 0.2941995522050218.
#  -> Epoch 1/150 || LOSS - train: 0.361110, val: 0.093600 | MSE - train: 0.361110, val: 0.093600 | RMSE - train: 0.600924, val: 0.305942 | LR: 3.06e-05
# ================ Training Complete ================
#  Best Epoch: 56, with LOSS: 0.086442, MSE: 0.086442 and RMSE: 0.294009 ==================
# UT val metrics | MAE: 2.749699, MSE: 21.475183, RMSE: 4.634132, mean summed abs err: 552.689523
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.011 | RMSE: 4.634 | mean-curve RMSE: 4.633 | skill vs mean curve: -0.000315 | peak corr: -0.0529 | energy corr: -0.0663 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.0147, RMSE 1.151 | peak_region: collapse 0.00996, RMSE 7.455 | post_peak: collapse 0.0131, RMSE 2.743
# [I 2026-05-14 22:20:09,504] Trial 1 finished with value: 0.29400943268840835 and parameters: {'gcn_act': 'gelu', 'gcn_norm': None, 'gcn_dropout': 0.08133258269081609, 'gcn_head_dropout': 0.07773545793789641, 'gcn_depth': 3, 'gcn_width': 128, 'gcn_att_dropout': 0.2807689432639139, 'gcn_head_norm': 'layer', 'gcn_pool': 'mean', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 3.058656942932557e-05, 'weight_decay': 0.0001194832816854543, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 15, 'early_stop': True, 'early_stop_patience': 25}. Best is trial 1 with value: 0.29400943268840835.
#  -> Epoch 1/150 || LOSS - train: 0.102725, val: 0.087764 | MSE - train: 0.102725, val: 0.087764 | RMSE - train: 0.320507, val: 0.296249 | LR: 2.79e-04
# ================ Training Complete ================
#  Best Epoch: 35, with LOSS: 0.086404, MSE: 0.086404 and RMSE: 0.293946 ==================
# UT val metrics | MAE: 2.750363, MSE: 21.464924, RMSE: 4.633025, mean summed abs err: 552.823050
# Best prediction: 394, Worst prediction: 472
# UT VAL prediction diagnostics | collapse ratio: 0.00419 | RMSE: 4.633 | mean-curve RMSE: 4.633 | skill vs mean curve: -7.56e-05 | peak corr: 0.0197 | energy corr: -0.0447 | sample curve corr: 0.986
# UT VAL zones | elastic: collapse 0.0052, RMSE 1.15 | peak_region: collapse 0.00341, RMSE 7.453 | post_peak: collapse 0.00627, RMSE 2.743
# [I 2026-05-14 23:05:49,473] Trial 2 finished with value: 0.2939457547156456 and parameters: {'gcn_act': 'mish', 'gcn_norm': None, 'gcn_dropout': 0.22180318564408164, 'gcn_head_dropout': 0.09444298503238986, 'gcn_depth': 4, 'gcn_width': 128, 'gcn_att_dropout': 0.1829564902836979, 'gcn_head_norm': None, 'gcn_pool': 'mean', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.0002794455147238025, 'weight_decay': 3.730610475453584e-07, 'batch': 8, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 8, 'early_stop': True, 'early_stop_patience': 25}. Best is trial 2 with value: 0.2939457547156456.
#  -> Epoch 1/150 || LOSS - train: 585.980136, val: 10.519739 | MSE - train: 1.151556, val: 0.550527 | RMSE - train: 1.073106, val: 0.741975 | LR: 7.01e-05

# %% [markdown]
# ### MODEL

# %%
GNN1 = MODEL(
    typ=DAT.model,
    model=GNN(in_size=DAT.UT_train_in.shape[-1], 
              h_size=[64, 64, 64, 64],
              out_size=DAT.UT_train_out.shape[-1], 
              act="relu",
              block="gat",
              norm="layer",
              dropout=0.2,
              bias=True,
              heads=2,
              pool="mean").to(device),
    lossf=nn.MSELoss(reduction="mean"),
    opt=("adam", 6.016e-6), #("adam", 1e-4),
    batch=36,
    lr=9e-4,
    data=DAT,
    mechMode=DAT.mechMode,
    scheduler=("min", 0.2427, 100, 1e-4), 
    earlyStop=EarlyStopping(patience=150, min_delta=1e-4, verbose=True),
    w_init="auto",
    device=device,
    optTrial=None,
    scan_matches_on_init=True
)

GNN1.summary()

# %%
GNN1.train(n_epochs=1000, verbose=20, plot=True)

# %%
GNN1.save(path=None, name=None)

# %%
GNN1.predict(test_dataloader=None, plot=True)

# %%
for i in range(len(GNN1.UT_test_outputs)):
    plot_predictions(DAT.UT_OUT_df, GNN1.UT_test_outputs, GNN1.UT_truth, indx=i, d_out=False)

# %% [markdown]
# ## Transformer

# %% [markdown]
# ### DATA

# %%
DAT_TR = DATA(
    path=1, 
    path_add="",
    load=True, 
    load_split=False,
    split_frac=0.9,
    split_seed=42,
    range_split=(True, False),
    save_split=False,
    LAT="FCC", 
    dis="disNodes", 
    dN=0.2,
    d_data="in",
    mechMode="UT",
    nsims=None,
    model="TR",
    scale=("symm", "inout"),
    reduce_dim=False, #("PCA", "out", 0.95, 10, True)
    round_decimals=5,
    geom_feats=(True, True)
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
DAT = DAT_TR
if DAT.UTmechTest:
    print("UT shape:", DAT.UT_train_in.shape, DAT.UT_train_out.shape)
    print("Train -  in (min, max):", DAT.UT_train_in.min(), DAT.UT_train_in.max(), "\n        out (min, max):", DAT.UT_train_out.min(), DAT.UT_train_out.max())
    print("  Val -  in (min, max):", DAT.UT_val_in.min(), DAT.UT_val_in.max(), "\n        out (min, max):", DAT.UT_val_out.min(), DAT.UT_val_out.max())
    print(" Test -  in (min, max):", DAT.UT_test_in.min(), DAT.UT_test_in.max(), "\n        out (min, max):", DAT.UT_test_out.min(), DAT.UT_test_out.max())
    if DAT.FTmechTest: print("\n========================================================\n")
if DAT.FTmechTest:
    print("FT shape:", DAT.FT_train_in.shape, DAT.FT_train_out.shape)
    print("Train -  in (min, max):", DAT.FT_train_in.min(), DAT.FT_train_in.max(), "\n        out (min, max):", DAT.FT_train_out.min(), DAT.FT_train_out.max())
    print("  Val -  in (min, max):", DAT.FT_val_in.min(), DAT.FT_val_in.max(), "\n        out (min, max):", DAT.FT_val_out.min(), DAT.FT_val_out.max())
    print(" Test -  in (min, max):", DAT.FT_test_in.min(), DAT.FT_test_in.max(), "\n        out (min, max):", DAT.FT_test_out.min(), DAT.FT_test_out.max())
# Out:
# UT shape: (5561, 800, 8) (5561, 201)
# Train -  in (min, max): -1.0 1.0
#         out (min, max): -1.0 1.0
#   Val -  in (min, max): -1.0 1.0
#         out (min, max): -1.6191947669483455 1.103937947512592
#  Test -  in (min, max): -1.0 1.0
#         out (min, max): -1.595077081066206 1.0862485225493743

# %% [markdown]
# ### HPO

# %%
# HYPERPARAMETER OPTIMIZATION HERE.
# Full HPO run on the full Transformer DATA split. Re-running resumes the saved Optuna study.

TR_hOpt_model_space = {
    "d_model": [32, 64, 128],
    "n_heads": [1, 2, 4, 8],
    "n_layers": [1, 2, 3],
    "ff_mult": [2, 4],
    "head_depth": [0, 1, 2],
    "head_width": [64, 128, 256],
    "pool": ["mean", "cls"],
    "use_cls_token": [True, False],
    "act": ["relu", "gelu"],
    "encoder_act": ["gelu", "relu"],
    "block": ["mlp", "res"],
    "norm": ["layer"],
    "dropout": {"type": "float", "low": 0.0, "high": 0.25},
    "att_dropout": {"type": "float", "low": 0.0, "high": 0.20},
    "head_norm": ["same", None, "layer"],
    "head_dropout": {"type": "float", "low": 0.0, "high": 0.20},
    "pos_encoding": ["learned", "sinusoidal"],
}

TR_hOpt_loss_space = {
    "family": ["mse", "combined"],
    "mse_weight": [0.25, 0.5, 1.0],
    "weighted_mse_weight": [0.0, 0.5, 1.0, 2.0],
    "derivative_weight": [0.0, 0.02, 0.05, 0.10],
    "peak_weight": [0.0, 0.10, 0.25, 0.50],
    "energy_weight": [0.0, 0.05, 0.10, 0.25],
    "peak_location_weight": [0.0, 0.02, 0.05],
    "reduction": ["mean"],
    "derivative_order": [1],
    "SoftPeak_beta": [10.0, 20.0, 40.0],
    "UT": {
        "zone_boundaries": (65, 130),
        "zone_weights": (1.0, 5.0, 0.2),
    },
    "FT": {
        "zone_boundaries": (85, 160),
        "zone_weights": (1.0, 5.0, 0.2),
    },
}

TR_hOpt_train_space = {
    "optimizer": ["adamw"],
    "lr": {"type": "float", "low": 3e-5, "high": 1e-3, "log": True},
    "weight_decay": {"type": "float", "low": 1e-8, "high": 1e-3, "log": True},
    "batch": [4, 8, 16],
    "n_epochs": {"type": "fixed", "value": 150},
    "metric": ["rmse"],
    "scheduler": ["plateau"],
    "scheduler_factor": [0.3, 0.5],
    "scheduler_patience": [8, 15],
    "scheduler_threshold": {"type": "fixed", "value": 1e-4},
    "early_stop": [True],
    "early_stop_patience": [25, 40],
    "early_stop_min_delta": {"type": "fixed", "value": 1e-5},
    "verbose": {"type": "fixed", "value": 0},
}

study_TR_full = hOpt_model(
    typ="tr",
    data=DAT_TR,
    n_trials=35,
    model_space=TR_hOpt_model_space,
    loss_space=TR_hOpt_loss_space,
    train_space=TR_hOpt_train_space,
    seed=42,
    device=device,
    save=True,
    save_best_model=True,
    name="TR_full_hOpt",
    n_jobs=1,
    show_progress_bar=True,
)

hOpt_best_summary(study_TR_full)
# Out:
# c:\Programs\Python39\lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# c:\Programs\Python39\lib\site-packages\optuna\_experimental.py:33: ExperimentalWarning: Argument ``group`` is an experimental feature. The interface can change in the future.
#   optuna_warn(
# C:\Users\exy053\Documents\00-PhD-gitRepo\resources\MLfunc.py:2269: ExperimentalWarning: PatientPruner is experimental (supported from v2.8.0). The interface can change in the future.
#   pruner = optuna.pruners.PatientPruner(base_pruner, patience=5) if hasattr(optuna.pruners, "PatientPruner") else base_pruner
# [I 2026-05-06 22:02:17,151] A new study created in RDB with name: TR_full_hOpt
#   0%|          | 0/35 [00:00<?, ?it/s]
# c:\Programs\Python39\lib\site-packages\torch\nn\modules\transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
#  -> Epoch 1/150 || LOSS - train: 0.100586, val: 0.087133 | MSE - train: 0.100586, val: 0.087133 | RMSE - train: 0.317153, val: 0.295183 | LR: 3.30e-04
# ================ Training Complete ================
#  Best Epoch: 47, with LOSS: 0.086385, MSE: 0.086385 and RMSE: 0.293913 ==================
# [I 2026-05-07 02:05:06,101] Trial 0 finished with value: 0.2939125272185462 and parameters: {'tr_act': 'gelu', 'tr_norm': 'layer', 'tr_dropout': 0.18299848545285127, 'tr_head_dropout': 0.11973169683940732, 'tr_d_model': 32, 'tr_n_heads': 1, 'tr_pool': 'mean', 'tr_use_cls_token': True, 'tr_head_depth': 2, 'tr_head_width': 256, 'tr_n_layers': 3, 'tr_ff_mult': 4, 'tr_encoder_act': 'relu', 'tr_head_block': 'mlp', 'tr_att_dropout': 0.12150897038028768, 'tr_head_norm': 'layer', 'tr_pos_encoding': 'learned', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00033046478547966453, 'weight_decay': 1.5876781526923984e-06, 'batch': 8, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 8, 'early_stop': True, 'early_stop_patience': 40}. Best is trial 0 with value: 0.2939125272185462.
#  -> Epoch 1/150 || LOSS - train: 0.074036, val: 0.069299 | MSE - train: 0.104988, val: 0.095588 | RMSE - train: 0.324018, val: 0.309174 | LR: 7.82e-04
# ================ Training Complete ================
#  Best Epoch: 34, with LOSS: 0.064684, MSE: 0.087278 and RMSE: 0.295429 ==================
# [I 2026-05-07 09:39:25,483] Trial 1 finished with value: 0.2954289272820964 and parameters: {'tr_act': 'gelu', 'tr_norm': 'layer', 'tr_dropout': 0.19378320584027864, 'tr_head_dropout': 0.18789978831283782, 'tr_d_model': 128, 'tr_n_heads': 8, 'tr_pool': 'mean', 'tr_use_cls_token': True, 'tr_head_depth': 1, 'tr_head_width': 256, 'tr_n_layers': 1, 'tr_ff_mult': 2, 'tr_encoder_act': 'relu', 'tr_head_block': 'res', 'tr_att_dropout': 0.023173811905025946, 'tr_head_norm': 'same', 'tr_pos_encoding': 'sinusoidal', 'loss_family': 'combined', 'mse_weight': 0.5, 'weighted_mse_weight': 1.0, 'derivative_weight': 0.0, 'peak_weight': 0.5, 'energy_weight': 0.1, 'peak_location_weight': 0.02, 'loss_reduction': 'mean', 'loss_derivative_order': 1, 'loss_SoftPeak_beta': 20.0, 'optimizer': 'adamw', 'lr': 0.0007815163153444284, 'weight_decay': 0.00010979988817809666, 'batch': 8, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 15, 'early_stop': True, 'early_stop_patience': 25}. Best is trial 0 with value: 0.2939125272185462.
# c:\Programs\Python39\lib\site-packages\torch\nn\modules\transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
#  -> Epoch 1/150 || LOSS - train: 0.127361, val: 0.087175 | MSE - train: 0.127361, val: 0.087175 | RMSE - train: 0.356876, val: 0.295255 | LR: 2.75e-04
# ================ Training Complete ================
#  Best Epoch: 56, with LOSS: 0.086394, MSE: 0.086394 and RMSE: 0.293929 ==================
# [I 2026-05-07 13:08:05,202] Trial 2 finished with value: 0.29392902224254286 and parameters: {'tr_act': 'gelu', 'tr_norm': 'layer', 'tr_dropout': 0.10677694715656408, 'tr_head_dropout': 0.16360295318449863, 'tr_d_model': 32, 'tr_n_heads': 1, 'tr_pool': 'mean', 'tr_use_cls_token': False, 'tr_head_depth': 1, 'tr_head_width': 128, 'tr_n_layers': 3, 'tr_ff_mult': 2, 'tr_encoder_act': 'relu', 'tr_head_block': 'mlp', 'tr_att_dropout': 0.09789055205551261, 'tr_head_norm': 'same', 'tr_pos_encoding': 'learned', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00027545227564861415, 'weight_decay': 1.471121537912197e-05, 'batch': 16, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 15, 'early_stop': True, 'early_stop_patience': 25}. Best is trial 0 with value: 0.2939125272185462.
#  -> Epoch 1/150 || LOSS - train: 22.170370, val: 1.114307 | MSE - train: 0.343879, val: 0.243964 | RMSE - train: 0.586412, val: 0.493927 | LR: 3.78e-04
# ================ Training Complete ================
#  Best Epoch: 79, with LOSS: 0.881549, MSE: 0.086869 and RMSE: 0.294735 ==================
# [I 2026-05-08 04:53:28,779] Trial 3 finished with value: 0.2947349706623079 and parameters: {'tr_act': 'relu', 'tr_norm': 'layer', 'tr_dropout': 0.16129319760236246, 'tr_head_dropout': 0.03487328580099829, 'tr_d_model': 128, 'tr_n_heads': 8, 'tr_pool': 'mean', 'tr_use_cls_token': False, 'tr_head_depth': 0, 'tr_head_width': 256, 'tr_n_layers': 1, 'tr_ff_mult': 4, 'tr_encoder_act': 'gelu', 'tr_head_block': 'mlp', 'tr_att_dropout': 0.032325742818922754, 'tr_head_norm': 'same', 'tr_pos_encoding': 'sinusoidal', 'loss_family': 'combined', 'mse_weight': 0.5, 'weighted_mse_weight': 0.5, 'derivative_weight': 0.05, 'peak_weight': 0.0, 'energy_weight': 0.05, 'peak_location_weight': 0.02, 'loss_reduction': 'mean', 'loss_derivative_order': 1, 'loss_SoftPeak_beta': 10.0, 'optimizer': 'adamw', 'lr': 0.00037785765547013834, 'weight_decay': 2.534322108372481e-07, 'batch': 8, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.5, 'scheduler_patience': 8, 'early_stop': True, 'early_stop_patience': 40}. Best is trial 0 with value: 0.2939125272185462.
#  -> Epoch 1/150 || LOSS - train: 0.100495, val: 0.089357 | MSE - train: 0.100495, val: 0.089357 | RMSE - train: 0.317009, val: 0.298926 | LR: 2.28e-04
# ================ Training Complete ================
#  Best Epoch: 27, with LOSS: 0.086442, MSE: 0.086442 and RMSE: 0.294011 ==================
# [I 2026-05-08 11:38:44,724] Trial 4 finished with value: 0.2940108127197622 and parameters: {'tr_act': 'gelu', 'tr_norm': 'layer', 'tr_dropout': 0.2409049942723132, 'tr_head_dropout': 0.170601891093472, 'tr_d_model': 128, 'tr_n_heads': 8, 'tr_pool': 'mean', 'tr_use_cls_token': False, 'tr_head_depth': 0, 'tr_head_width': 64, 'tr_n_layers': 1, 'tr_ff_mult': 4, 'tr_encoder_act': 'relu', 'tr_head_block': 'mlp', 'tr_att_dropout': 0.15965903579335505, 'tr_head_norm': 'layer', 'tr_pos_encoding': 'learned', 'loss_family': 'mse', 'optimizer': 'adamw', 'lr': 0.00022791441300761434, 'weight_decay': 1.5125556736397544e-08, 'batch': 8, 'objective_metric': 'rmse', 'w_init': 'auto', 'scheduler': 'plateau', 'scheduler_factor': 0.3, 'scheduler_patience': 15, 'early_stop': True, 'early_stop_patience': 25}. Best is trial 0 with value: 0.2939125272185462.
#  -> Epoch 1/150 || LOSS - train: 0.123095, val: 0.087661 | MSE - train: 0.123095, val: 0.087661 | RMSE - train: 0.350849, val: 0.296076 | LR: 4.51e-05

# %% [markdown]
# ### MODEL

# %%
TR1 = MODEL(
    typ=DAT.model,
    model=Transformer(
        in_size=DAT.UT_train_in.shape[-1] if DAT.UTmechTest else DAT.FT_train_in.shape[-1],
        seq_len=DAT.UT_train_in.shape[-2] if DAT.UTmechTest else DAT.FT_train_in.shape[-2],
        h_size=[64],
        out_size=DAT.UT_train_out.shape[-1] if DAT.UTmechTest else DAT.FT_train_out.shape[-1],
        d_model=32,
        n_heads=4,
        n_layers=5,
        act="gelu",
        block="mlp",
        norm="layer",
        dropout=0.1,
        pool="mean"
    ).to(device),
    lossf={
    "UT":CombinedCurveLoss(
        mse_weight=1.0,
        weighted_mse_weight=3.0,
        derivative_weight=0.5,
        peak_weight=3.0,
        energy_weight=1.0,
        peak_location_weight=2.0,
        zone_boundaries=(65, 130),
        zone_weights=(1.0, 5.0, 0.2),
        x_values=DAT.UT_OUT_df if DAT.UTmechTest else None,
        reduction="mean",
        derivative_order=1,
        SoftPeak_beta=20.0,)}, 
    # "FT":CombinedCurveLoss(
    #     mse_weight=0.1,
    #     weighted_mse_weight=1.0,
    #     derivative_weight=0.5,
    #     peak_weight=0.2,
    #     energy_weight=0.2,
    #     peak_location_weight=0.05,
    #     zone_boundaries=(85, 160),
    #     zone_weights=(1.0, 5.0, 0.2),
    #     x_values=DAT.FT_OUT_df if DAT.FTmechTest else None,
    #     reduction="mean",
    #     derivative_order=1,
    #     SoftPeak_beta=20.0)
    # },
    opt=("adam", 6.016e-6), #("adam", 1e-4),
    batch=32,
    lr=1e-3,
    data=DAT,
    mechMode=DAT.mechMode,
    scheduler=("min", 0.2427, 15, 1e-4), #("min", 0.2427, 18, 1e-4), 
    earlyStop=EarlyStopping(patience=18, min_delta=1e-4, verbose=True),
    w_init="auto",
    device=device,
    optTrial=None,
    scan_matches_on_init=True
)

TR1.summary()

# %%
TR1.train(n_epochs=10, verbose=1, plot=True)

# %%
TR1.save(path=None, name=None)

# %%
TR1.predict(test_dataloader=None, plot=True)

# %%
for i in range(len(TR1.UT_test_outputs)):
   plot_predictions(DAT.UT_OUT_df, TR1.UT_test_outputs, TR1.UT_truth, indx=i, d_out=False)

# %% [markdown]
# # END

# %% [markdown]
# # Cleanup Ideas To Preserve
#
# ## 1. Uncertainty-Aware Curve Prediction
#
# Goal: predict not only the mean stress-strain curve, but also uncertainty bands or calibrated confidence estimates.
#
# Possible routes:
# - Use model ensembles or MC dropout for practical uncertainty estimates.
# - Add probabilistic output heads, e.g. mean + log-variance per curve point, trained with Gaussian negative log likelihood.
# - Explore mixture-density outputs if curves are genuinely multimodal.
# - Use GPR/BoTorch-style uncertainty only for low-dimensional latent or optimization tasks, since full stress-strain curves are likely too high-dimensional for direct GPR.
#
# Why useful:
# - Could identify unreliable predictions.
# - Could support active learning or simulation selection.
# - Could make optimization less overconfident.
#
# ## 2. Physics / Constraint Loss Extensions
#
# Goal: encode simple mechanical expectations into training loss without forcing a full PINN formulation.
#
# Current framework already includes curve-aware losses: weighted curve MSE, derivative loss, peak stress, strain energy, and soft peak location. Future extensions should build on those rather than resurrect the old PINN notebooks.
#
# Possible constraints:
# - Penalize negative stress where physically invalid.
# - Encourage monotonic early elastic response.
# - Penalize unrealistic oscillations or sharp nonphysical jumps.
# - Add stiffness/slope consistency in the initial strain region.
# - Add energy consistency using area under the curve.
# - Add fracture/peak-region constraints separately for UT and FT.
#
# Why useful:
# - Keeps predictions mechanically plausible.
# - May improve extrapolation.
# - More compatible with current supervised framework than full DeepXDE/PINN code.
#
# Related idea:
# - Deep Ritz methods minimize an energy or variational functional rather than a pointwise PDE residual. This may be more relevant than a generic PINN for mechanics problems, but any future version should be rebuilt as a curve/energy-aware supervised loss or field-level model, not revived from the old notebook. **For predicting displacement/stress fields directly from geometry, Deep Ritz-style ideas might be more mechanically natural than a generic PINN**.
#
# ## 3. Generative Augmentation
#
# Goal: generate plausible additional disorder-response examples or latent perturbations to improve robustness.
#
# Preferred future routes:
# - Use the existing Autoencoder as a starting point for latent-space augmentation.
# - Consider conditional VAE-style generation before GANs.
# - Use generative models to propose candidate inputs, then validate with FEA or active learning.
# - Avoid using generated stress-strain curves as ground truth unless physically verified.
#
# Why useful:
# - Could help sparse regions of design/disorder space.
# - Could support optimization and active sampling.
# - Might expose structure in the learned latent representation.
#
# Caution:
# The old GAN notebook is not a good implementation basis. Any generative method should be rebuilt around the current DATA, MODEL, scaling/reconstruction, and diagnostics pipeline.
