# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset

# %%
# %run MLdata.ipynb
# %run MLfunc.ipynb

# %% [markdown]
# ## GANs

# %% [raw]
# input_dim = train_in.shape[-1]
# output_dim = train_out.shape[-1]
#
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# class Generator(nn.Module):
#     def __init__(self, input_dim, output_dim, latent_dim=128):
#         super(Generator, self).__init__()
#         self.model = nn.Sequential(nn.Linear(input_dim + latent_dim, 256),
#                                    nn.LeakyReLU(0.2),
#                                    nn.Linear(256, 512),
#                                    nn.LeakyReLU(0.2),
#                                    nn.Linear(512, 1024),
#                                    nn.LeakyReLU(0.2),
#                                    nn.Linear(1024, output_dim))
#
#     def forward(self, noise, displacements):
#         x = torch.cat((noise, displacements), dim=1)  # Concatenating noise + displacements
#         print(x)
#         return self.model(x)
#
#
# class Discriminator(nn.Module):
#     def __init__(self, input_dim, output_dim):
#         super(Discriminator, self).__init__()
#         self.model = nn.Sequential(nn.Linear(output_dim + input_dim, 512),
#                                    nn.LeakyReLU(0.2),
#                                    nn.Linear(512, 256),
#                                    nn.LeakyReLU(0.2),
#                                    nn.Linear(256, 128),
#                                    nn.LeakyReLU(0.2),
#                                    nn.Linear(128, 1),
#                                    nn.Sigmoid())  # Output probability score
#
#     def forward(self, displacements, stress_diff):
#         x = torch.cat((displacements, stress_diff), dim=1)  # Concatenating inputs
#         return self.model(x)
#
#
# # Initialize networks
# generator = Generator(input_dim, output_dim).to(device)
# discriminator = Discriminator(input_dim, output_dim).to(device)
#
# # Loss function and optimizers
# criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for GAN training
# optimizer_G = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
# optimizer_D = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
#
# # Training parameters
# BATCH_SIZE = 64
# epochs = 500
# latent_dim = 128
#
# trainDS = Dataset(train_in, train_out)
# valDS = Dataset(val_in, val_out)
# testDS = Dataset(test_in, test_out)
#
# train_dataloader = DataLoader(dataset=trainDS, batch_size=BATCH_SIZE, shuffle=True)
# val_dataloader = DataLoader(dataset=valDS, batch_size=BATCH_SIZE, shuffle=True)
# test_dataloader = DataLoader(dataset=testDS, batch_size=BATCH_SIZE, shuffle=False)
#
# for epoch in range(epochs+1):
#     for x, y in train_dataloader:
#         # Generate noise and sample displacements
#         noise = torch.randn(batch_size, latent_dim).to(device)
#         real_displacements = x
#         real_delta_stress = y
#
#         # Generate fake stress values
#         fake_delta_stress = generator(noise, real_displacements)
#
#         # Train Discriminator
#         optimizer_D.zero_grad()
#         real_validity = discriminator(real_displacements, real_delta_stress)
#         fake_validity = discriminator(real_displacements, fake_delta_stress.detach())
#         d_loss = -(torch.mean(real_validity) - torch.mean(fake_validity))  # Wasserstein loss
#         d_loss.backward()
#         optimizer_D.step()
#
#         # Train Generator
#         optimizer_G.zero_grad()
#         fake_validity = discriminator(real_displacements, fake_delta_stress)
#         g_loss = -torch.mean(fake_validity)  # Generator tries to fool discriminator
#         g_loss.backward()
#         optimizer_G.step()
#
#     # Print training progress
#     if epoch % 50 == 0:
#         print(f"Epoch {epoch}/{epochs} | D Loss: {d_loss.item()} | G Loss: {g_loss.item()}")
